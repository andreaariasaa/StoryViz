# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading data into dataframes
main_df = pd.read_csv('Data/main_table.csv', index_col=0)
hh_df = pd.read_csv('Data/hh_roster.csv', index_col=0)
ext_df = pd.read_csv('Data/mig_ext_roster.csv', index_col=0)
int_df = pd.read_csv('Data/mig_int_roster.csv', index_col=0)
pend_df = pd.read_csv('Data/mig_pend_roster.csv', index_col=0)
lookup = pd.read_excel('Data/survey data look-up table.xlsx', sheet_name='answer_lookup')
main_type = pd.read_excel('Data/survey data look-up table.xlsx', sheet_name='main_table')

# %%
from Analytical_Functions import *
from Data_Functions import *

# %%
plot_data(main_df, 'hh_income_first')
# Out:
# 8.1a Main source to cover basic needs:
#                                                     count   pct
# hh_income_first
# Own production (agricultural, livestock and fis...    555  0.11
# Jornaleo (agricultural, farming and fishing)         1174  0.23
# Government employment (teacher, health worker, ...    265  0.05
# Employment in private company                         513  0.10
# Employment in NGO or international organization        19  0.00
# Non-agricultural work (housework, hairdresser, ...    765  0.15
# Informal trade or street vending                      236  0.05
# Small-scale own business (store / pulpería, ven...    422  0.08
# Own business on a larger scale                         77  0.02
# Self-employment (professional services, etc.)          61  0.01
# Assistance from the government or any other act...     41  0.01
# Migrant remittances abroad                            413  0.08
# Money from people who migrate or have migrated ...     46  0.01
# Help from family and / or friends                     168  0.03
# Other                                                 207  0.04
# I have no other way of life                            36  0.01

# %%
plot_data(main_df, 'rsp_sex')
# Out:
# 2.1 What is the sex of the person surveyed?
#                      count   pct
# rsp_sex
# Woman                 3675  0.74
# Man                   1322  0.26
# I prefer not to say      1  0.00

# %%
plot_data(main_df, 'mig_int_pref_motivo')
# Out:
#
#
# 3.7 What are the main reasons why you would like to move to another part of the country? (multiple choice, total response:1183)
#                                                     count   pct
# mig_int_pref_motivo
# A family member has a job in another part of th...   60.0  0.05
# By the direct impact of a natural hazard             39.0  0.03
# Due to loss of land due to processes of land us...    6.0  0.01
# Due to the deterioration of livelihoods due to ...   51.0  0.04
# For domestic violence                                 6.0  0.01
# For threats or extortion                             44.0  0.04
# NS / NR                                               7.0  0.01
# Other                                               166.0  0.14
# To become independent or start my own family         74.0  0.06
# To find a larger and / or more comfortable spac...  221.0  0.19
# To find better job opportunities                    987.0  0.83
# To seek better academic or study opportunities      100.0  0.08

# %%
plot_data(main_df, 'avg_income_amount')
# Out:
#
#
# 8.6.2 Monthly income:
#    index  avg_income_amount
# 0  count            3083.00
# 1   mean             296.64
# 2    std             400.78
# 3    min               0.00
# 4    25%             124.90
# 5    50%             200.00
# 6    75%             328.00
# 7    max            8450.00

# %%
plot_data(main_df, 'mig_ext_intention')
# Out:
# 3.1 Ideally, if you had the opportunity, would you like to move permanently or for a long period to another country?
#                    count   pct
# mig_ext_intention
# Not                 2769  0.55
# Yes                 2153  0.43
# NS / NR               76  0.02

# %%
plot_data(main_df, 'mig_ext_plan_12months')
# Out:
# 3.3 Are you planning to move to another country in the next 12 months?
#                        count   pct
# mig_ext_plan_12months
# Not                     1812  0.84
# Yes                      322  0.15
# NS / NR                   19  0.01

# %%
plot_data(main_df, 'mig_ext_preparacion')
# Out:
# 3.5 Have you made any preparation to move to another country?
#                      count  pct
# mig_ext_preparacion
# Not                    161  0.5
# Yes                    160  0.5
# NS / NR                  1  0.0

# %%
plot_data(main_df, 'remittances_yn')
# Out:
# 3.30 In the last 12 months, has your household received financial aid from abroad?
#                 count   pct
# remittances_yn
# Not              3532  0.71
# Yes              1447  0.29
# NS / NR            19  0.00

# %%
new_df = narrow_data(main_df, 'remittances_yn', 'Yes')

plot_data(new_df, 'mig_ext_intention')
# Out:
# 3.1 Ideally, if you had the opportunity, would you like to move permanently or for a long period to another country?
#                    count   pct
# mig_ext_intention
# Not                  694  0.48
# Yes                  731  0.51
# NS / NR               22  0.02

# %%
plot_data(main_df, 'preocupaciones_first')
# Out:
# First concern:
#                                                     count   pct
# preocupaciones_first
# Fear of contagion of COVID-19                        2354  0.47
# Limitations or restrictions on mobility due to ...    116  0.02
# Can't afford to buy food                              716  0.14
# Lack of work / unemployment                           775  0.16
# Insecurity / violence                                 134  0.03
# Difficulty paying the rent or loan                    101  0.02
# Interruption or irregularity in educational ser...     20  0.00
# Interruption of medical services                       68  0.01
# Medicines shortage                                     82  0.02
# Public transport shortage                               6  0.00
# Lack of water                                          55  0.01
# Persecution / discrimination                            2  0.00
# Fear of facing a natural threat (hurricanes, vo...    141  0.03
# Other                                                 129  0.03
# Without worries                                       299  0.06

# %%
plot_data(main_df, 'nivel_violencia')
# Out:
# 12.5 Do you consider that in the last year violence in the place where you live has:
#                          count   pct
# nivel_violencia
# Increased                  712  0.14
# Diminished                 792  0.16
# Same / No change          1600  0.32
# No violent acts / crime   1641  0.33
# NS / NR                    253  0.05

# %%
new_df = narrow_data(main_df, 'nivel_violencia', 'Increased')

plot_data(new_df, 'mig_ext_intention')
# Out:
# 3.1 Ideally, if you had the opportunity, would you like to move permanently or for a long period to another country?
#                    count   pct
# mig_ext_intention
# Not                  361  0.51
# Yes                  336  0.47
# NS / NR               15  0.02

# %%
plot_data(ext_df, 'mig_ext_cost_currency')

new_df = narrow_data(ext_df, 'mig_ext_cost_currency', 'Dollars')

plot_data(new_df, 'mig_ext_cost_total')
# Out:
# 3.19.1 Please indicate the currency with which you will enter the cost of the trip to the country of destination
#                        count   pct
# mig_ext_cost_currency
# Dollars                  369  0.45
# Lempiras                 106  0.13
# Quetzals                 342  0.42
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/r1/jp90tfsx3cs2q4gc4vd2bj680000gn/T/ipykernel_954/1018843890.py in <module>
#       1 plot_data(ext_df, 'mig_ext_cost_currency')
#       2
# ----> 3 new_df = narrow_data(ext_df, 'mig_ext_cost_currency', 'Dollars')
#       4
#       5 plot_data(new_df, 'mig_ext_cost_total')
#
# ~/Documents/GitHub/StoryViz/DataAnalysis/Data_Functions.py in narrow_data(current_df, question, result)
#      10
#      11 # Given a dataframe, question, and result, it will
# ---> 12 # filter over the dataframe and return a new DataFrame
#      13 # that applies to this result
#      14 def narrow_data(current_df, question, result):
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
plot_data(main_df, 'econ_condition')
# Out:
# 13.2 Right now, do you think that the economic conditions in the area where you live are getting better or worse?
#                      count   pct
# econ_condition
# 0                       45  0.01
# Worse                 1597  0.32
# It remains the same   2585  0.52
# Getting better         682  0.14
# NS / NR                 89  0.02

# %%
plot_data(main_df, 'econ_condition')

new_df = narrow_data(main_df, 'econ_condition', 'It remains the same')

plot_data(new_df, 'mig_ext_intention')
# Out:
# 13.2 Right now, do you think that the economic conditions in the area where you live are getting better or worse?
#                      count   pct
# econ_condition
# 0                       45  0.01
# Worse                 1597  0.32
# It remains the same   2585  0.52
# Getting better         682  0.14
# NS / NR                 89  0.02
# 3.1 Ideally, if you had the opportunity, would you like to move permanently or for a long period to another country?
#                    count   pct
# mig_ext_intention
# Not                 1484  0.57
# Yes                 1071  0.41
# NS / NR               30  0.01

# %%
plot_data(main_df, 'living_condition')

new_df = narrow_data(main_df, 'living_condition', 'Getting better')

plot_data(new_df, 'mig_ext_intention')
# Out:
# 13.3 At this moment, do you feel that your standard of living is improving or deteriorating?
#                      count   pct
# living_condition
# 0                       47  0.01
# Worse                 1498  0.30
# It remains the same   2770  0.55
# Getting better         637  0.13
# NS / NR                 46  0.01
# 3.1 Ideally, if you had the opportunity, would you like to move permanently or for a long period to another country?
#                    count   pct
# mig_ext_intention
# Not                  360  0.57
# Yes                  264  0.41
# NS / NR               13  0.02

# %%
plot_data(main_df, 'income_satisfaction')

new_df = narrow_data(main_df, 'income_satisfaction', 'We are in a very critical situation with current income')

plot_data(new_df, 'living_condition')

next_df = narrow_data(new_df, 'living_condition', 'Worse')

plot_data(next_df, 'mig_ext_intention')

# next_next_df = narrow_data(next_df, 'econ_condition', 'Worse')

# plot_data(next_next_df, 'mig_ext_intention')

n_n_n_df = narrow_data(next_df, 'mig_ext_intention', 'Yes')

plot_data(n_n_n_df, 'mig_ext_preparacion')

n_n_n_n_df = narrow_data(n_n_n_df, 'mig_ext_preparacion', 'Not')

plot_data(n_n_n_n_df, 'mig_int_pref_no_plan')

plot_data(next_next_df, 'remittances_yn')

plot_data(next_next_df, 'mig_int_pref_motivo')

plot_data(next_next_df, 'hh_income_first')
# Out:
# 13.5 Which of these statements is closest to how you feel about your household income these days?
#                                                     count   pct
# income_satisfaction
# We live comfortably on current income                 796  0.16
# We survive on current income                         2393  0.48
# We are struggling with current income                1175  0.24
# We are in a very critical situation with curren...    604  0.12
# NS / NR                                                30  0.01
# 13.3 At this moment, do you feel that your standard of living is improving or deteriorating?
#                      count   pct
# living_condition
# 0                        6  0.01
# Worse                  340  0.56
# It remains the same    217  0.36
# Getting better          37  0.06
# NS / NR                  4  0.01
# 3.1 Ideally, if you had the opportunity, would you like to move permanently or for a long period to another country?
#                    count   pct
# mig_ext_intention
# Not                  139  0.41
# Yes                  196  0.58
# NS / NR                5  0.01
# 3.5 Have you made any preparation to move to another country?
#                      count   pct
# mig_ext_preparacion
# Not                     25  0.61
# Yes                     16  0.39
#
#
# 3.9 What are the main reasons why you have not planned to move to another part of the country in the next 12 months? (multiple choice, total response:7)
#                                                     count   pct
# mig_int_pref_no_plan
# For fear that something will happen to him due ...    1.0  0.14
# For the fear of contagion of COVID-19                 2.0  0.29
# I don't have enough resources to pay for anothe...    5.0  0.71
# I don't have enough resources to pay for living...    2.0  0.29
# I don't have enough resources to pay for the tr...    2.0  0.29
# I don't want to abandon my family and / or friends    2.0  0.29
# I have not had time to plan the move                  0.0  0.00
# My family disagrees with my moving to another p...    0.0  0.00
# NS / NR                                               0.0  0.00
# Other                                                 1.0  0.14
# 3.30 In the last 12 months, has your household received financial aid from abroad?
#                 count   pct
# remittances_yn
# Not               221  0.84
# Yes                41  0.16
#
#
# 3.7 What are the main reasons why you would like to move to another part of the country? (multiple choice, total response:85)
#                                                     count   pct
# mig_int_pref_motivo
# A family member has a job in another part of th...    3.0  0.04
# By the direct impact of a natural hazard              4.0  0.05
# Due to loss of land due to processes of land us...    1.0  0.01
# Due to the deterioration of livelihoods due to ...   12.0  0.14
# For domestic violence                                 0.0  0.00
# For threats or extortion                              1.0  0.01
# NS / NR                                               0.0  0.00
# Other                                                 7.0  0.08
# To become independent or start my own family          4.0  0.05
# To find a larger and / or more comfortable spac...   22.0  0.26
# To find better job opportunities                     74.0  0.87
# To seek better academic or study opportunities        8.0  0.09
# 8.1a Main source to cover basic needs:
#                                                     count   pct
# hh_income_first
# Own production (agricultural, livestock and fis...     12  0.05
# Jornaleo (agricultural, farming and fishing)           79  0.30
# Government employment (teacher, health worker, ...      8  0.03
# Employment in private company                          28  0.11
# Non-agricultural work (housework, hairdresser, ...     60  0.23
# Informal trade or street vending                       14  0.05
# Small-scale own business (store / pulpería, ven...     14  0.05
# Own business on a larger scale                          1  0.00
# Self-employment (professional services, etc.)           3  0.01
# Assistance from the government or any other act...      2  0.01
# Migrant remittances abroad                              8  0.03
# Help from family and / or friends                      14  0.05
# Other                                                  17  0.06
# I have no other way of life                             2  0.01

# %%
plot_data(main_df, 'hh_income_first')
# Out:
# 8.1a Main source to cover basic needs:
#                                                     count   pct
# hh_income_first
# Own production (agricultural, livestock and fis...    555  0.11
# Jornaleo (agricultural, farming and fishing)         1174  0.23
# Government employment (teacher, health worker, ...    265  0.05
# Employment in private company                         513  0.10
# Employment in NGO or international organization        19  0.00
# Non-agricultural work (housework, hairdresser, ...    765  0.15
# Informal trade or street vending                      236  0.05
# Small-scale own business (store / pulpería, ven...    422  0.08
# Own business on a larger scale                         77  0.02
# Self-employment (professional services, etc.)          61  0.01
# Assistance from the government or any other act...     41  0.01
# Migrant remittances abroad                            413  0.08
# Money from people who migrate or have migrated ...     46  0.01
# Help from family and / or friends                     168  0.03
# Other                                                 207  0.04
# I have no other way of life                            36  0.01

# %%
plot_data(main_df, 'confidence_election')

new_df = narrow_data(main_df, 'confidence_election', 'Not')

plot_data(new_df, 'income_satisfaction')

next_df = narrow_data(new_df, 'income_satisfaction', 'We are in a very critical situation with current income')

plot_data(next_df, 'mig_ext_intention')
# Out:
# 13.7 In this country, do you have confidence in the honesty of the elections of the country's rulers?
#                      count   pct
# confidence_election
# Not                   3251  0.65
# Yes                   1396  0.28
# NS / NR                351  0.07
# 13.5 Which of these statements is closest to how you feel about your household income these days?
#                                                     count   pct
# income_satisfaction
# We live comfortably on current income                 542  0.17
# We survive on current income                         1610  0.50
# We are struggling with current income                 715  0.22
# We are in a very critical situation with curren...    371  0.11
# NS / NR                                                13  0.00
# 3.1 Ideally, if you had the opportunity, would you like to move permanently or for a long period to another country?
#                    count   pct
# mig_ext_intention
# Not                  165  0.44
# Yes                  203  0.55
# NS / NR                3  0.01
